# %%
from sklearn.datasets import make_classification

# %%
x, y = make_classification(
    n_samples=1000,
    n_features=2,
    n_clusters_per_class=1,
    weights=[0.90],
    random_state=12,
    n_redundant=0,
)

# %%
import pandas as pd

df1 = pd.DataFrame(x, columns=['f1', 'f2'])
df2 = pd.DataFrame(y, columns=['target'])
df = pd.concat([df1, df2], axis=1)
df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(df['f1'], df['f2'], c = df['target'])

# %%
# Install the imblearn package
# %pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=12)

# %%
X_resampled, y_resampled = smote.fit_resample(x, y)
df_resampled = pd.DataFrame(X_resampled, columns=['f1', 'f2'])
df_resampled['target'] = y_resampled
df_resampled['target'].value_counts()
df_resampled.head()
df_resampled['target'].value_counts().plot(kind='bar')
plt.show()
plt.scatter(df_resampled['f1'], df_resampled['f2'], c = df_resampled['target'])
